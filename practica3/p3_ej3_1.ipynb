# %% [markdown]
# ### Universidad de Granada | ETSIIT
#
#
# ---
# # **Práctica 3**: Redes Neuronales Convolucionales
# ---
# **Asignatura:** Visión por Computador
#
# **Autor:** Lugli, Valentino Glauco · YB0819879

# %% [markdown]
# ## **Preámbulo**
# ### Añadiendo las librerías y funciones en común de los ejercicios necesarias para realizar la práctica.

# %%
# LIBRERÍAS

#   Usando Matplotlib para mostrar imágenes
import matplotlib.pyplot as plt
import matplotlib.colors as clr

#   Usando OpenCV para el resto de cosas con imágenes
import cv2 as cv

#   Usando Numpy para cálculos matriciales
import numpy as np

#   Usando Math para funciones matemáticas avanzadas
import math

#   Usando Random para obtener puntos
import random

#   Usando keras y tensorflow para las redes
import tensorflow as tf
import tensorflow.keras as k
import tensorflow.keras.utils as np_utils
from keras.models import Sequential

# Importar el conjunto de datos
from keras.datasets import cifar100

# Importando nombres de las capas por legibilidad
from keras.layers import Conv2D, Dense, MaxPooling2D, Flatten, BatchNormalization, Dropout, UpSampling2D

# Cosas para ResNet50
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input

# Imports para hacer el conjunto de validación
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from keras.preprocessing.image import load_img,img_to_array

# Importando el recolector de basura
import gc

#########################################################################
## FUNCIÓN PARA PINTAR LA PÉRDIDA Y EL ACCURACY EN TRAIN Y VALIDACIÓN ###
#########################################################################

# Esta función pinta dos gráficas, una con la evolución de la función
# de pérdida en el conjunto de train y en el de validación, y otra
# con la evolución del accuracy en el conjunto de train y en el de
# validación. Es necesario pasarle como parámetro el historial
# del entrenamiento del modelo (lo que devuelven las funciones
# fit() y fit_generator()).

def mostrarEvolucion(hist):

  #plt.figure(figsize=(4,3), dpi= 200)
  loss = hist.history['loss']
  val_loss = hist.history['val_loss']
  plt.plot(loss)
  plt.plot(val_loss)
  plt.legend(['Training loss', 'Validation loss'])
  plt.show()

  #plt.figure(figsize=(4,3), dpi= 200)
  acc = hist.history['accuracy']
  val_acc = hist.history['val_accuracy']
  plt.plot(acc)
  plt.plot(val_acc)
  plt.legend(['Training accuracy', 'Validation accuracy'])
  plt.show()


#########################################################################
################## FUNCIÓN PARA LEER LAS IMÁGENES #######################
#########################################################################

# Dado un fichero train.txt o test.txt y el path donde se encuentran los
# ficheros y las imágenes, esta función lee las imágenes
# especificadas en ese fichero y devuelve las imágenes en un vector y 
# sus clases en otro.

def leerImagenes(vec_imagenes, path):
  clases = np.array([img.split('/')[0] for img in vec_imagenes])
  imagenes = np.array([img_to_array(load_img(path + "/" + img, 
                                             target_size = (224, 224))) 
                       for img in vec_imagenes])
  imagenes.astype(np.float32)
  return imagenes, clases


#########################################################################
############# FUNCIÓN PARA CARGAR EL CONJUNTO DE DATOS ##################
#########################################################################

# Usando la función anterior, y dado el path donde se encuentran las
# imágenes y los archivos "train.txt" y "test.txt", devuelve las 
# imágenes y las clases de train y test para usarlas con keras
# directamente.

def cargarDatos(path):
  # Cargamos los ficheros
  train_images = np.loadtxt(path + "/train.txt", dtype = str)
  test_images = np.loadtxt(path + "/test.txt", dtype = str)
  
  # Leemos las imágenes con la función anterior
  train, train_clases = leerImagenes(train_images, path)
  test, test_clases = leerImagenes(test_images, path)
  
  # Pasamos los vectores de las clases a matrices 
  # Para ello, primero pasamos las clases a números enteros
  clases_posibles = np.unique(np.copy(train_clases))
  for i in range(len(clases_posibles)):
    train_clases[train_clases == clases_posibles[i]] = i
    test_clases[test_clases == clases_posibles[i]] = i

  # Después, usamos la función to_categorical()
  train_clases = np_utils.to_categorical(train_clases, 200)
  test_clases = np_utils.to_categorical(test_clases, 200)
  
  # Barajar los datos
  train_perm = np.random.permutation(len(train))
  train = train[train_perm]
  train_clases = train_clases[train_perm]

  test_perm = np.random.permutation(len(test))
  test = test[test_perm]
  test_clases = test_clases[test_perm]
  
  return train, train_clases, test, test_clases

# Callback nuevo para llamar al recolector de basura al final de cada época.
class GarbageCollectorCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        gc.collect()


def getDataIterators(train_x, train_y, test_x, batches):
    """
      Generador de iteradores dados los datos de entrada, 
      no realiza aumento de datos pero se utiliza para
      poder utilizar la misma función que utiliza el fit.   

    Parameters
    ----------
    train_x : Lista de imagenes de entrenamiento
    train_y : Lista de etiquetas de entrenamiento
    test_x : Lista de imágenes de prueba
    batches: Numero de batches de entrenamiento.

    Returns
    -------
    it_train: Iterador de imágenes de entrenamiento.
    it_validation: Iterador de imágenes de validación.
    test_x: Imágenes de test ajustadas a los parámetros de entrenamiento.

    """  

    # Obtener iterador de IDG
    dataG = ImageDataGenerator()
    
    # Hacer el fit a los datos de entrenamiento.
    dataG.fit(train_x)
    
    # Realizar la división entre entrenamiento y validación con la función.
    X_train, X_val, Y_train, Y_val = train_test_split(train_x, train_y, test_size=0.1, stratify=train_y)
    
    # Obtener el iterador de entrenamiento.
    it_train = dataG.flow(X_train , Y_train, batch_size = batches)

    # Obtener el iterador de validación.
    it_validation = dataG.flow(X_val , Y_val)

    # Obtener el iterador de test.
    dataT = ImageDataGenerator()
    
    # Hacer fit con los datos de entrenamiento
    dataT.fit(train_x)

    # Estandarizar los datos de test con los de entrenamiento.
    dataT.standardize(test_x)

    return it_train, it_validation, test_x



def getAugDataIterators(train_x, train_y, test_x, batches):
    """
      Generador de iteradores dados los datos de entrada, 
      con aumento de datos.

    Parameters
    ----------
    train_x : Lista de imagenes de entrenamiento
    train_y : Lista de etiquetas de entrenamiento
    test_x : Lista de imágenes de prueba
    batches: Numero de batches de entrenamiento.

    Returns
    -------
    it_train: Iterador de imágenes de entrenamiento.
    it_validation: Iterador de imágenes de validación.
    test_x: Imágenes de test ajustadas a los parámetros de entrenamiento.

    """  

    # Aumento de datos, se añade: 
    # -Rotación hasta 10º
    # -Cambios de posición vertical y horizontal
    # -Voltear la imagen horizontalmente.
    dataG = ImageDataGenerator(rotation_range=10, 
                               width_shift_range=0.2, 
                               height_shift_range=0.2,
                               horizontal_flip=True)
    
    # Hacer el fit a los datos de entrenamiento.
    dataG.fit(train_x)
    
    # Realizar la división entre entrenamiento y validación con la función.
    X_train, X_val, Y_train, Y_val = train_test_split(train_x, train_y, test_size=0.1, stratify=train_y)

    # Obtener el iterador de entrenamiento.
    it_train = dataG.flow(X_train , Y_train, batch_size = batches)

    # Obtener el iterador de validación.
    it_validation = dataG.flow(X_val , Y_val)

    # Obtener el iterador de test.
    dataT = ImageDataGenerator()
    
    # Hacer fit con los datos de entrenamiento
    dataT.fit(train_x)

    # Estandarizar los datos de test con los de entrenamiento.
    dataT.standardize(test_x)

    return it_train, it_validation, test_x

def compileModel(model):
    """
      Compilar un modelo dado unos parámetros por defecto.

    Parameters
    ----------
    model: Red neuronal

    Returns
    -------
    None

    """      
    # Compilando el modelo con función de pérdida de entropía cruzada categórica
    # con el optimizador Adam en parámetros por defecto y con la métrica de 
    # precisión a los datos.
    model.compile(loss = k.losses.categorical_crossentropy,
              optimizer = 'adam',
              metrics = ['accuracy'])


def trainModel(model, train_x, val_x, batchSize, trainEpochs):
    """
    Entrenar una red convolucional

    Parameters
    ----------
    model: Modelo de Keras
      Modelo que se desea entrenar.

    train_x: Iterador de los datos de entrenamiento.
    
    val_x: Iterador de los datos de validación.

    batchSize: Tamaño del batch

    trainEpochs: Número de épocas en las que entrenar.

    Returns
    -------
    hist: Objeto que contiene el historial de entrenamiento de la red.

    """  
    # Se crea el callback del recolector de basura
    gcCallBack = GarbageCollectorCallback()

    # Se entrena la red.
    hist = model.fit(train_x, batch_size=batchSize, epochs=trainEpochs, 
                     validation_data = val_x, verbose=1, 
                     callbacks=[gcCallBack])

    return hist

def testModel(model, text_x, test_y, hist):
    """
    Evalúa el modelo en el conjunto de datos de test

    Parameters
    ----------
    model: Modelo de Keras

    test_x: Lista de imágenes de test
    test_y: Lista de etiquetas de test
    hist: Objeto que contiene el historial de entrenamiento

    Returns
    -------
    None

    """  

    # Se muetra la gráfica de entrenamiento y validación.
    mostrarEvolucion(hist)
    print("Evaluando...")
    # Se evalúa e imprimen los datos de pérdida y precisión.
    score = model.evaluate(text_x, test_y, verbose=1)
    print("Resultados de Evaluación en Test\n - Loss:", score[0])
    print(' - Accuracy: ', score[1] * 100,"%")

def getResNet50(p_pooling, inputShape):
    """
      Obtener un modelo de la red ResNet50

    Parameters
    ----------
    p_pooling: String
      Indica que clase de Pooling se desea.

    inputShape: Tupla
      Indica la forma que tendrá la entrada a la red.

    Returns
    -------
    model: Modelo de ResNet

    """  
    # Se obtiene una red ResNet50, con los pesos entrenados a ImageNet, siempre
    # se obvía el clasificador con top = False.
    model = ResNet50(weights = 'imagenet', include_top = False, input_shape = inputShape, pooling = p_pooling)
    return model

def getBirdNetV1(model, onlyFinal):
    """
      Obtener la versión 0 y 1 de BirdNet

    Parameters
    ----------
    model: Modelo de Keras
      Modelo base del cual construir BirdNet

    onlyFinal: Booleano
      Indica si solo se utilizará solo el clasificador nuevo.

    Returns
    -------
    model: Modelo de BirdNet

    """  
  
    # Se hacen que las capas de ResNet no puedan sen entrnadas.
    for layer in model.layers:
      layer.trainable = False

    # Se obtiene la última capa de ResNet para conectar el resto.
    x = model.output

    # Si es BirdNetV1, incluir estas capas:
    if(not onlyFinal):

      x = (Dense(1024, activation="relu")) (x)

      x = (Dropout(0.5)) (x)

      x = (Dense(512, activation='relu')) (x)

    # Añadir el clasificador
    lastLayer = Dense(200, activation='softmax') (x)

    # Generar un modelo nuevo con las capas adicionales e incluyendo a ResNet
    retModel = k.Model(inputs = model.inputs, outputs = lastLayer)

    return retModel

def getBirdNetV2(model):
    """
      Obtener la versión 2 de BirdNet

    Parameters
    ----------
    model: Modelo de Keras
      Modelo base del cual construir BirdNet

    Returns
    -------
    model: Modelo de BirdNet

    """  

    # Ídem con la función anterior
    for layer in model.layers:
      layer.trainable = False

    x = model.output

    x = Conv2D(64, 3, padding='same', activation='relu') (x)

    x = BatchNormalization() (x)

    x = Flatten() (x)

    x = Dense(256, activation='relu') (x)

    lastLayer = Dense(200, activation='softmax') (x)

    retModel = k.Model(inputs = model.inputs, outputs = lastLayer)

    return retModel


def getBirdNetV3(model):
    """
      Obtener la versión 3 de BirdNet

    Parameters
    ----------
    model: Modelo de Keras
      Modelo base del cual construir BirdNet

    onlyFinal: Booleano
      Indica si solo se utilizará solo el clasificador nuevo.

    Returns
    -------
    model: Modelo de BirdNet

    """  

    #Ídem con la versión anterior.
    x = model.output
    
    lastLayer = Dense(200, activation='softmax') (x)

    retModel = k.Model(inputs = model.inputs, outputs = lastLayer)

    return retModel


def getBirdNetV4(model):
    """
      Obtener la versión 0 y 1 de BirdNet

    Parameters
    ----------
    model: Modelo de Keras
      Modelo base del cual construir BirdNet

    onlyFinal: Booleano
      Indica si solo se utilizará solo el clasificador nuevo.

    Returns
    -------
    model: Modelo de BirdNet

    """  

    # Ídem con la versión anterior, pero ahora no se colocan directamente los
    # pesos a no entrenables.
    x = model.output
    x = Dense(512, activation="relu")(x)
    x = Dropout(0.5)(x)
    lastLayer = Dense(200, activation="softmax")(x)

    retModel = k.Model(inputs = base.inputs, outputs = lastLayer)

    return retModel

# %% [markdown]
# ---
# ##**Ejercicio 3**

# %% [markdown]
# ### Carga de los datos
#
# Solamente necesario realizarlo una vez cuando se inicia el Notebook.

# %%
# Montando el espacio de trabajo
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# El fichero 'imagenes.zip' debe de tener incluido dentro los ficheros de texto
# 'train.txt' y 'test.txt'.

# Se descomprime dentro del espacio privado de Google Colab.
# !unzip "/content/drive/MyDrive/Colab Notebooks/imagenes.zip" -d "/content/"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/imagenes/021.Eastern_Towhee/._Eastern_Towhee_0020_2599674379.jpg
#   inflating: /content/imagenes/021.Eastern_Towhee/._Eastern_Towhee_0010_2509455869.jpg
#   inflating: /content/imagenes/021.Eastern_Towhee/Eastern_Towhee_0017_2187908406.jpg
#   inflating: /content/imagenes/021.Eastern_Towhee/._Eastern_Towhee_0025_2616290973.jpg
#   inflating: /content/imagenes/021.Eastern_Towhee/Eastern_Towhee_0001_3030801645.jpg
#   inflating: /content/imagenes/021.Eastern_Towhee/Eastern_Towhee_0009_2509457459.jpg
#   inflating: /content/imagenes/021.Eastern_Towhee/Eastern_Towhee_0029_2465368346.jpg
#   inflating: /content/imagenes/021.Eastern_Towhee/._Eastern_Towhee_0021_2923789659.jpg
#   inflating: /content/imagenes/021.Eastern_Towhee/._Eastern_Towhee_0005_2509456875.jpg
#   inflating: /content/imagenes/021.Eastern_Towhee/Eastern_Towhee_0030_59209663.jpg
#   inflating: /content/imagenes/021.Eastern_Towhee/._Eastern_Towhee_0004_2510292984.jpg
#   inflating: /content/imagenes/021.Eastern_Towhee/._Eastern_Towhee_0027_457837690.jpg
#   inflating: /content/imagenes/021.Eastern_Towhee/Eastern_Towhee_0021_2923789659.jpg
#   inflating: /content/imagenes/021.Eastern_Towhee/._Eastern_Towhee_0006_2482856289.jpg
#   inflating: /content/imagenes/021.Eastern_Towhee/._Eastern_Towhee_0008_2509458021.jpg
#   inflating: /content/imagenes/021.Eastern_Towhee/Eastern_Towhee_0019_2601828200.jpg
#   inflating: /content/imagenes/021.Eastern_Towhee/Eastern_Towhee_0027_457837690.jpg
#   inflating: /content/imagenes/021.Eastern_Towhee/._Eastern_Towhee_0012_2510289770.jpg
#   inflating: /content/imagenes/021.Eastern_Towhee/._Eastern_Towhee_0016_2398947381.jpg
#   inflating: /content/imagenes/021.Eastern_Towhee/._Eastern_Towhee_0019_2601828200.jpg
#   inflating: /content/imagenes/021.Eastern_Towhee/Eastern_Towhee_0011_2509458597.jpg
#   inflating: /content/imagenes/021.Eastern_Towhee/._Eastern_Towhee_0018_120628317.jpg
#   inflating: /content/imagenes/021.Eastern_Towhee/Eastern_Towhee_0015_2509454417.jpg
#   inflating: /content/imagenes/021.Eastern_Towhee/Eastern_Towhee_0012_2510289770.jpg
#   inflating: /content/imagenes/021.Eastern_Towhee/Eastern_Towhee_0024_2545961689.jpg
#   inflating: /content/imagenes/021.Eastern_Towhee/._Eastern_Towhee_0009_2509457459.jpg
#   inflating: /content/imagenes/021.Eastern_Towhee/Eastern_Towhee_0013_2510292416.jpg
#    creating: /content/imagenes/094.White_breasted_Nuthatch/
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0008_60262680.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0002_60246540.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0023_2391498884.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0009_2220839395.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0015_2965905174.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0017_2214118073.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0005_2300658207.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0010_231978653.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0035_2296313148.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0021_2072773154.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0031_2422656153.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0020_85856766.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0019_2933773443.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0024_2285091720.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0033_1389808690.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0007_2988186882.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0006_144310340.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0018_1483165079.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0026_2069673754.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0006_144310340.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0025_2270721090.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0013_253748267.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0003_2395842591.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0024_2285091720.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0028_266988951.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0001_2922319182.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0018_1483165079.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0034_2096387688.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0029_2035492906.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0033_1389808690.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0016_1909649033.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0022_1679760112.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0029_2035492906.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0004_3017329557.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0014_3003005775.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0032_2358349030.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0032_2358349030.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0025_2270721090.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0011_1537796381.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0019_2933773443.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0030_377915966.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0012_92711488.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0004_3017329557.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0002_60246540.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0011_1537796381.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0007_2988186882.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0022_1679760112.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0005_2300658207.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0012_92711488.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0023_2391498884.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0014_3003005775.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0030_377915966.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0034_2096387688.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0013_253748267.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0010_231978653.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0035_2296313148.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0016_1909649033.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0027_2866108873.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0009_2220839395.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0015_2965905174.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0003_2395842591.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0017_2214118073.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0031_2422656153.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0027_2866108873.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0020_85856766.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0001_2922319182.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0026_2069673754.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0028_266988951.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/._White_breasted_Nuthatch_0008_60262680.jpg
#   inflating: /content/imagenes/094.White_breasted_Nuthatch/White_breasted_Nuthatch_0021_2072773154.jpg
#    creating: /content/imagenes/188.Pileated_Woodpecker/
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0026_521909839.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0038_xxx.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0003_2330469006.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0017_3069887706.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0025_2323249191.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0031_557818634.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0011_500265513.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0019_2214120511.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0039_2921473905.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0009_2319572557.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0036_25993104.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0027_2193787661.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0005_xxx.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0006_2443246132.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0013_2120896468.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0019_2214120511.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0031_557818634.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0012_541439754.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0010_335659352.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0011_500265513.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0037_2977491420.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0012_541439754.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0009_2319572557.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0027_2193787661.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0001_2875831137.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0026_521909839.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0020_2089578608.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0016_2337115721.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0003_2330469006.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0036_25993104.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0028_2483563065.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0020_2089578608.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0039_2921473905.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0004_2434360945.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0007_335659040.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0022_2215309855.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0010_335659352.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0024_2823376764.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0001_2875831137.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0008_2138487935.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0024_2823376764.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0035_335778326.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0023_2215310347.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0022_2215309855.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0017_3069887706.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0038_xxx.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0023_2215310347.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0029_2482167878.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0014_xxx.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0007_335659040.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0033_2860440897.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0018_2422973262.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0037_2977491420.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0033_2860440897.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0029_2482167878.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0034_2434362429.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0002_2189400753.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0016_2337115721.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0005_xxx.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0004_2434360945.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0028_2483563065.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0035_335778326.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0034_2434362429.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0013_2120896468.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0032_641457996.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0008_2138487935.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0018_2422973262.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0030_99606483.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0014_xxx.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0025_2323249191.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0015_1975835733.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0032_641457996.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0015_1975835733.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0002_2189400753.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0021_25993105.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/Pileated_Woodpecker_0006_2443246132.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0030_99606483.jpg
#   inflating: /content/imagenes/188.Pileated_Woodpecker/._Pileated_Woodpecker_0021_25993105.jpg
#    creating: /content/imagenes/010.Red_winged_Blackbird/
#   inflating: /content/imagenes/010.Red_winged_Blackbird/Red_winged_Blackbird_0016_102414646.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/._Red_winged_Blackbird_0007_495139194.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/Red_winged_Blackbird_0027_2419463190.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/._Red_winged_Blackbird_0006_2376861574.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/Red_winged_Blackbird_0015_469101656.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/Red_winged_Blackbird_0006_2376861574.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/Red_winged_Blackbird_0026_2201165026.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/._Red_winged_Blackbird_0024_16024607.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/._Red_winged_Blackbird_0002_138027313.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/Red_winged_Blackbird_0023_519203903.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/._Red_winged_Blackbird_0009_2472004320.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/Red_winged_Blackbird_0018_2477592974.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/Red_winged_Blackbird_0011_495139158.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/Red_winged_Blackbird_0008_469101650.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/Red_winged_Blackbird_0010_465415726.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/._Red_winged_Blackbird_0026_2201165026.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/Red_winged_Blackbird_0017_583846699.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/._Red_winged_Blackbird_0025_2460801057.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/Red_winged_Blackbird_0025_2460801057.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/._Red_winged_Blackbird_0020_474690970.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/Red_winged_Blackbird_0009_2472004320.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/._Red_winged_Blackbird_0003_2435737741.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/._Red_winged_Blackbird_0012_2472606189.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/._Red_winged_Blackbird_0021_2529270051.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/._Red_winged_Blackbird_0015_469101656.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/Red_winged_Blackbird_0004_2209034288.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/Red_winged_Blackbird_0007_495139194.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/._Red_winged_Blackbird_0014_144916612.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/Red_winged_Blackbird_0005_865242258.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/Red_winged_Blackbird_0002_138027313.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/._Red_winged_Blackbird_0004_2209034288.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/Red_winged_Blackbird_0019_398266170.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/._Red_winged_Blackbird_0008_469101650.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/Red_winged_Blackbird_0001_2370065784.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/Red_winged_Blackbird_0024_16024607.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/Red_winged_Blackbird_0012_2472606189.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/._Red_winged_Blackbird_0005_865242258.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/._Red_winged_Blackbird_0011_495139158.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/._Red_winged_Blackbird_0018_2477592974.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/Red_winged_Blackbird_0013_139596958.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/._Red_winged_Blackbird_0017_583846699.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/._Red_winged_Blackbird_0022_2179939448.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/._Red_winged_Blackbird_0001_2370065784.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/Red_winged_Blackbird_0021_2529270051.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/._Red_winged_Blackbird_0016_102414646.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/Red_winged_Blackbird_0022_2179939448.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/._Red_winged_Blackbird_0023_519203903.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/._Red_winged_Blackbird_0013_139596958.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/Red_winged_Blackbird_0003_2435737741.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/Red_winged_Blackbird_0014_144916612.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/._Red_winged_Blackbird_0010_465415726.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/._Red_winged_Blackbird_0019_398266170.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/._Red_winged_Blackbird_0027_2419463190.jpg
#   inflating: /content/imagenes/010.Red_winged_Blackbird/Red_winged_Blackbird_0020_474690970.jpg
#   inflating: /content/imagenes/._182.Yellow_Warbler
#    creating: /content/imagenes/075.Green_Jay/
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0027_2934474095.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0013_2266239562.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0024_xxx.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0015_1805161969.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0023_2371805731.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0021_3033141323.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0008_2034171253.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0010_435779818.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0019_2332356584.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0031_477899172.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0029_2458635659.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0007_2034971972.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0025_2087886415.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0005_1805387582.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0001_2067893425.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0008_2034171253.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0006_2347756935.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0010_435779818.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0034_2143966592.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0028_3092617898.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0016_3033141729.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0027_2934474095.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0004_1806016442.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0016_3033141729.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0004_1806016442.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0030_649594018.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0037_2394662980.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0001_2067893425.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0007_2034971972.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0018_2189441891.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0031_477899172.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0012_1351255526.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0017_2310877631.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0005_1805387582.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0036_2892831425.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0037_2394662980.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0026_772259577.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0024_xxx.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0032_2434280614.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0014_287786620.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0013_2266239562.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0033_390572264.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0017_2310877631.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0003_360514395.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0035_2983226963.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0022_2347763099.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0006_2347756935.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0003_360514395.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0021_3033141323.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0011_361246576.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0036_2892831425.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0034_2143966592.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0012_1351255526.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0023_2371805731.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0033_390572264.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0020_2190321162.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0014_287786620.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0025_2087886415.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0009_2275212527.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0002_1804533131.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0035_2983226963.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0002_1804533131.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0032_2434280614.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0018_2189441891.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0029_2458635659.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0020_2190321162.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0009_2275212527.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0011_361246576.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0022_2347763099.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0028_3092617898.jpg
#   inflating: /content/imagenes/075.Green_Jay/Green_Jay_0026_772259577.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0030_649594018.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0015_1805161969.jpg
#   inflating: /content/imagenes/075.Green_Jay/._Green_Jay_0019_2332356584.jpg
#    creating: /content/imagenes/154.Red_eyed_Vireo/
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0001_2879184061.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0013_2880017344.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0004_2805679283.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0016_2917350638.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0026_2502710393.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0008_2693140149.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0024_2879181819.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0031_2740243174.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0018_525553976.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0024_2879181819.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0002_2697832838.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0002_2697832838.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0010_2224604942.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0015_2916506313.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0014_18090319.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0011_2224577638.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0006_2928288319.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0031_2740243174.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0014_18090319.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0026_2502710393.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0034_500254638.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0003_59210336.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0023_2880018380.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0030_305729945.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0009_2748298992.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0029_59210443.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0020_2693135269.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0015_2916506313.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0003_59210336.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0008_2693140149.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0012_531934627.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0022_2693134681.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0011_2224577638.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0019_504726670.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0021_2693953672.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0023_2880018380.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0030_305729945.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0007_2545288204.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0005_2850972890.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0010_2224604942.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0019_504726670.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0034_500254638.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0027_2503540454.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0021_2693953672.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0025_2502711037.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0009_2748298992.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0032_2851633441.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0016_2917350638.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0001_2879184061.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0006_2928288319.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0013_2880017344.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0018_525553976.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0022_2693134681.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0020_2693135269.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0033_2495509969.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0004_2805679283.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0032_2851633441.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0012_531934627.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0005_2850972890.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0029_59210443.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0007_2545288204.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0033_2495509969.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0017_2693952976.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0028_2502711347.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0017_2693952976.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/._Red_eyed_Vireo_0027_2503540454.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0028_2502711347.jpg
#   inflating: /content/imagenes/154.Red_eyed_Vireo/Red_eyed_Vireo_0025_2502711037.jpg
#    creating: /content/imagenes/051.Horned_Grebe/
#   inflating: /content/imagenes/051.Horned_Grebe/Horned_Grebe_0003_125903368.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/._Horned_Grebe_0010_2418064372.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/Horned_Grebe_0006_2406366514.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/._Horned_Grebe_0009_2403825611.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/._Horned_Grebe_0022_2475222460.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/Horned_Grebe_0011_2422362921.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/._Horned_Grebe_0015_489603154.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/Horned_Grebe_0017_2557685232.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/._Horned_Grebe_0030_152339016.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/._Horned_Grebe_0023_2532589196.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/Horned_Grebe_0005_433780719.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/._Horned_Grebe_0019_2560864345.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/Horned_Grebe_0026_2477021833.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/._Horned_Grebe_0024_2448319793.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/Horned_Grebe_0002_541151301.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/Horned_Grebe_0007_483366483.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/._Horned_Grebe_0026_2477021833.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/._Horned_Grebe_0002_541151301.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/Horned_Grebe_0028_461994149.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/Horned_Grebe_0027_2397986492.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/Horned_Grebe_0015_489603154.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/Horned_Grebe_0021_1348470102.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/._Horned_Grebe_0001_126910713.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/._Horned_Grebe_0003_125903368.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/._Horned_Grebe_0025_2618471390.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/Horned_Grebe_0029_2657978318.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/Horned_Grebe_0001_126910713.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/Horned_Grebe_0023_2532589196.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/Horned_Grebe_0016_453576293.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/Horned_Grebe_0014_2437138531.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/._Horned_Grebe_0017_2557685232.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/Horned_Grebe_0008_298319847.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/._Horned_Grebe_0021_1348470102.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/._Horned_Grebe_0008_298319847.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/Horned_Grebe_0004_2416449145.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/Horned_Grebe_0020_2407939885.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/Horned_Grebe_0013_2128032556.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/Horned_Grebe_0010_2418064372.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/._Horned_Grebe_0006_2406366514.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/._Horned_Grebe_0029_2657978318.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/._Horned_Grebe_0012_2376500154.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/Horned_Grebe_0030_152339016.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/._Horned_Grebe_0004_2416449145.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/._Horned_Grebe_0013_2128032556.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/._Horned_Grebe_0014_2437138531.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/._Horned_Grebe_0018_226926678.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/._Horned_Grebe_0007_483366483.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/._Horned_Grebe_0011_2422362921.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/Horned_Grebe_0022_2475222460.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/Horned_Grebe_0009_2403825611.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/._Horned_Grebe_0020_2407939885.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/._Horned_Grebe_0028_461994149.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/Horned_Grebe_0024_2448319793.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/._Horned_Grebe_0005_433780719.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/Horned_Grebe_0012_2376500154.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/Horned_Grebe_0019_2560864345.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/Horned_Grebe_0018_226926678.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/._Horned_Grebe_0016_453576293.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/._Horned_Grebe_0027_2397986492.jpg
#   inflating: /content/imagenes/051.Horned_Grebe/Horned_Grebe_0025_2618471390.jpg
#    creating: /content/imagenes/145.Elegant_Tern/
#   inflating: /content/imagenes/145.Elegant_Tern/._Elegant_Tern_0019_2779934570.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/._Elegant_Tern_0001_2800524137.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/Elegant_Tern_0002_2822361979.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/._Elegant_Tern_0016_2830978550.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/._Elegant_Tern_0025_2779076187.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/._Elegant_Tern_0026_2903116227.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/Elegant_Tern_0025_2779076187.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/._Elegant_Tern_0015_2900262061.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/Elegant_Tern_0014_2764982592.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/Elegant_Tern_0024_2779075787.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/Elegant_Tern_0005_2926101344.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/._Elegant_Tern_0007_2790427963.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/._Elegant_Tern_0011_2925248079.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/._Elegant_Tern_0004_2801373070.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/._Elegant_Tern_0017_2764150817.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/._Elegant_Tern_0021_2712184106.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/Elegant_Tern_0003_2800523347.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/Elegant_Tern_0018_2654123838.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/._Elegant_Tern_0023_2779933874.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/._Elegant_Tern_0008_2829066321.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/._Elegant_Tern_0014_2764982592.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/Elegant_Tern_0020_2819782382.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/Elegant_Tern_0013_2900264063.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/Elegant_Tern_0021_2712184106.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/Elegant_Tern_0009_2900261407.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/Elegant_Tern_0011_2925248079.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/Elegant_Tern_0017_2764150817.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/._Elegant_Tern_0022_2903960188.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/Elegant_Tern_0022_2903960188.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/._Elegant_Tern_0009_2900261407.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/Elegant_Tern_0010_2901109698.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/._Elegant_Tern_0005_2926101344.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/Elegant_Tern_0007_2790427963.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/._Elegant_Tern_0013_2900264063.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/._Elegant_Tern_0010_2901109698.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/Elegant_Tern_0001_2800524137.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/._Elegant_Tern_0003_2800523347.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/._Elegant_Tern_0024_2779075787.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/Elegant_Tern_0015_2900262061.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/Elegant_Tern_0006_2790917589.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/Elegant_Tern_0026_2903116227.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/._Elegant_Tern_0006_2790917589.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/._Elegant_Tern_0002_2822361979.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/Elegant_Tern_0016_2830978550.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/._Elegant_Tern_0020_2819782382.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/._Elegant_Tern_0012_2903115523.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/Elegant_Tern_0012_2903115523.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/._Elegant_Tern_0018_2654123838.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/Elegant_Tern_0023_2779933874.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/Elegant_Tern_0008_2829066321.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/Elegant_Tern_0019_2779934570.jpg
#   inflating: /content/imagenes/145.Elegant_Tern/Elegant_Tern_0004_2801373070.jpg
#    creating: /content/imagenes/086.Pacific_Loon/
#   inflating: /content/imagenes/086.Pacific_Loon/._Pacific_Loon_0007_177308274.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/._Pacific_Loon_0015_180115555.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/Pacific_Loon_0036_2535866038.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/._Pacific_Loon_0021_180115556.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/._Pacific_Loon_0020_709516077.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/._Pacific_Loon_0010_507612554.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/._Pacific_Loon_0004_179398407.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/._Pacific_Loon_0019_1111653041.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/._Pacific_Loon_0014_2709223862.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/._Pacific_Loon_0024_709516053.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/._Pacific_Loon_0009_3042531412.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/Pacific_Loon_0006_177308270.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/Pacific_Loon_0010_507612554.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/Pacific_Loon_0018_207213537.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/._Pacific_Loon_0029_182013754.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/._Pacific_Loon_0011_2671391950.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/Pacific_Loon_0024_709516053.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/Pacific_Loon_0009_3042531412.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/Pacific_Loon_0003_2819895285.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/Pacific_Loon_0007_177308274.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/._Pacific_Loon_0016_179408777.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/Pacific_Loon_0002_177336378.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/._Pacific_Loon_0025_179436135.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/Pacific_Loon_0021_180115556.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/Pacific_Loon_0017_180115554.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/._Pacific_Loon_0022_179411134.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/Pacific_Loon_0005_2570818279.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/._Pacific_Loon_0035_2582788901.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/Pacific_Loon_0013_2819894999.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/Pacific_Loon_0032_543334932.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/._Pacific_Loon_0006_177308270.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/Pacific_Loon_0031_1111653067.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/Pacific_Loon_0030_2819895149.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/Pacific_Loon_0029_182013754.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/Pacific_Loon_0023_182013756.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/._Pacific_Loon_0028_2582788917.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/._Pacific_Loon_0023_182013756.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/Pacific_Loon_0004_179398407.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/._Pacific_Loon_0018_207213537.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/._Pacific_Loon_0026_194728445.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/Pacific_Loon_0034_702514636.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/._Pacific_Loon_0013_2819894999.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/._Pacific_Loon_0027_175830455.jpg
#   inflating: /content/imagenes/086.Pacific_Loon/._Pacific_Loon_0012_3092137231.jpg
# ...
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0017_2549337769.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0024_3006983248.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0036_1296793534.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0014_2929246967.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0031_2490239339.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0037_2651489536.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0002_2676566230.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0036_1296793534.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0007_404162345.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0038_2418154276.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0029_2537117646.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0001_2655074586.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0022_152212633.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0002_2676566230.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0005_507200201.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0026_2589289404.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0035_525042903.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0034_59200319.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0027_3093796544.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0016_1561167379.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0021_149448089.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0012_1769798260.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0032_144879271.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0032_144879271.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0017_2549337769.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0008_3024123594.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0013_2930106572.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0014_2929246967.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0009_474096170.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0005_507200201.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0006_2902349669.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0010_144879272.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0029_2537117646.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0038_2418154276.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0009_474096170.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0020_177390924.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0007_404162345.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0023_152212629.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0018_2606067375.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0027_3093796544.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0025_3006146567.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0010_144879272.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0021_149448089.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0003_2975199769.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0018_2606067375.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0028_2503181272.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0019_2123679005.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0008_3024123594.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0037_2651489536.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0028_2503181272.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0033_144879270.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0024_3006983248.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0004_1769798864.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0022_152212633.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0015_223617946.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0034_59200319.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0035_525042903.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0015_223617946.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0006_2902349669.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0030_2491055566.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0030_2491055566.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0016_1561167379.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0025_3006146567.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0026_2589289404.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0004_1769798864.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0031_2490239339.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0013_2930106572.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0012_1769798260.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0001_2655074586.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0023_152212629.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0011_1768952163.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0020_177390924.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/._Vesper_Sparrow_0003_2975199769.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0033_144879270.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0011_1768952163.jpg
#   inflating: /content/imagenes/131.Vesper_Sparrow/Vesper_Sparrow_0019_2123679005.jpg
#   inflating: /content/imagenes/._029.American_Crow
#   inflating: /content/imagenes/._098.Scott_Oriole
#   inflating: /content/imagenes/._066.Western_Gull
#   inflating: /content/imagenes/._061.Heermann_Gull
#   inflating: /content/imagenes/._190.Red_cockaded_Woodpecker
#    creating: /content/imagenes/067.Anna_Hummingbird/
#   inflating: /content/imagenes/067.Anna_Hummingbird/._Anna_Hummingbird_0017_1446131078.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/._Anna_Hummingbird_0005_312346225.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/._Anna_Hummingbird_0021_506747606.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/Anna_Hummingbird_0015_313265587.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/Anna_Hummingbird_0010_1739309872.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/._Anna_Hummingbird_0020_313265562.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/Anna_Hummingbird_0013_2218579032.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/Anna_Hummingbird_0009_409385231.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/._Anna_Hummingbird_0008_2306994898.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/Anna_Hummingbird_0008_2306994898.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/Anna_Hummingbird_0007_262766480.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/Anna_Hummingbird_0003_80672862.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/Anna_Hummingbird_0001_2221475899.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/._Anna_Hummingbird_0006_447873834.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/._Anna_Hummingbird_0009_409385231.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/Anna_Hummingbird_0019_352279636.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/Anna_Hummingbird_0021_506747606.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/Anna_Hummingbird_0016_2068932620.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/._Anna_Hummingbird_0002_2220440966.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/._Anna_Hummingbird_0016_2068932620.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/._Anna_Hummingbird_0007_262766480.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/Anna_Hummingbird_0002_2220440966.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/Anna_Hummingbird_0011_2189942577.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/Anna_Hummingbird_0004_313272384.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/._Anna_Hummingbird_0018_2960372684.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/._Anna_Hummingbird_0004_313272384.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/Anna_Hummingbird_0017_1446131078.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/._Anna_Hummingbird_0001_2221475899.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/Anna_Hummingbird_0018_2960372684.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/._Anna_Hummingbird_0019_352279636.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/._Anna_Hummingbird_0011_2189942577.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/Anna_Hummingbird_0005_312346225.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/._Anna_Hummingbird_0003_80672862.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/._Anna_Hummingbird_0012_312346223.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/._Anna_Hummingbird_0024_2320333696.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/Anna_Hummingbird_0014_2068108861.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/._Anna_Hummingbird_0010_1739309872.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/._Anna_Hummingbird_0013_2218579032.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/Anna_Hummingbird_0012_312346223.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/._Anna_Hummingbird_0023_2645207478.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/Anna_Hummingbird_0006_447873834.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/Anna_Hummingbird_0022_409275457.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/Anna_Hummingbird_0024_2320333696.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/Anna_Hummingbird_0020_313265562.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/Anna_Hummingbird_0023_2645207478.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/._Anna_Hummingbird_0022_409275457.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/._Anna_Hummingbird_0015_313265587.jpg
#   inflating: /content/imagenes/067.Anna_Hummingbird/._Anna_Hummingbird_0014_2068108861.jpg
#    creating: /content/imagenes/146.Forsters_Tern/
#   inflating: /content/imagenes/146.Forsters_Tern/._Forsters_Tern_0005_294035938.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/Forsters_Tern_0024_2811950699.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/._Forsters_Tern_0004_294035839.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/._Forsters_Tern_0007_308527199.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/._Forsters_Tern_0003_398105324.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/._Forsters_Tern_0012_2208266536.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/Forsters_Tern_0008_1501120971.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/._Forsters_Tern_0017_1013968744.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/._Forsters_Tern_0022_2816515926.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/Forsters_Tern_0010_1604267510.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/Forsters_Tern_0023_2815664833.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/Forsters_Tern_0025_2154718566.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/Forsters_Tern_0004_294035839.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/._Forsters_Tern_0008_1501120971.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/Forsters_Tern_0007_308527199.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/._Forsters_Tern_0019_2899106005.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/._Forsters_Tern_0006_1479833566.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/._Forsters_Tern_0025_2154718566.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/Forsters_Tern_0026_1352773504.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/._Forsters_Tern_0011_2234274249.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/._Forsters_Tern_0026_1352773504.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/Forsters_Tern_0013_2083114719.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/._Forsters_Tern_0002_294035898.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/Forsters_Tern_0002_294035898.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/._Forsters_Tern_0016_2718730358.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/._Forsters_Tern_0013_2083114719.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/Forsters_Tern_0015_2857554307.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/Forsters_Tern_0009_2779665089.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/Forsters_Tern_0014_2803159992.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/Forsters_Tern_0022_2816515926.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/._Forsters_Tern_0018_1288270890.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/._Forsters_Tern_0020_1415544260.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/._Forsters_Tern_0014_2803159992.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/Forsters_Tern_0003_398105324.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/._Forsters_Tern_0010_1604267510.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/._Forsters_Tern_0021_2141229140.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/._Forsters_Tern_0009_2779665089.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/._Forsters_Tern_0023_2815664833.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/Forsters_Tern_0021_2141229140.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/Forsters_Tern_0006_1479833566.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/Forsters_Tern_0011_2234274249.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/._Forsters_Tern_0024_2811950699.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/Forsters_Tern_0001_2785441587.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/Forsters_Tern_0005_294035938.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/Forsters_Tern_0012_2208266536.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/Forsters_Tern_0020_1415544260.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/._Forsters_Tern_0015_2857554307.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/Forsters_Tern_0017_1013968744.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/Forsters_Tern_0016_2718730358.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/Forsters_Tern_0018_1288270890.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/._Forsters_Tern_0001_2785441587.jpg
#   inflating: /content/imagenes/146.Forsters_Tern/Forsters_Tern_0019_2899106005.jpg
#   inflating: /content/imagenes/._047.American_Goldfinch
#   inflating: /content/imagenes/._139.Scarlet_Tanager

# %% [markdown]
# ### Inicialización de los datos básica

# %%
# Obteniendo las imágenes dada la función proporcionada.
train_x, train_y, test_x, test_y = cargarDatos("/content/imagenes")

# Realizandole el preprocesado de los datos.
train_x = preprocess_input(train_x)
test_x = preprocess_input(test_x)

# %% [markdown]
# ### Implementación del Ejercicio 3.1

# %%
# Obteniendo los iteradores sin aumento de datos
# - Si se realiza el aumento de datos en todos los ejercicios la memoria se llena más rápido
# - Se hicieron experimentos y aún con el aumento existe overfitting.
train_it, val_it, test_x = getDataIterators(train_x, train_y, test_x, 64)

# %%
#%% Apartado 3.1.1:
# "Eliminar las capas finales FC y la salida, substituirlas por nuevas FC y 
# salida y reentrenarlas con Caltech-UCSD. "

# Generando el modelo
base = getResNet50('avg', train_x[0].shape)
birdNet = getBirdNetV1(base, False)

# Mostrando el modelo
birdNet.summary()

# Compilando el modelo
compileModel(birdNet)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 14, 14, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block3_add[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['conv5_block3_out[0][0]']
#  2D)
#
#  dense (Dense)                  (None, 1024)         2098176     ['avg_pool[0][0]']
#
#  dropout (Dropout)              (None, 1024)         0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 512)          524800      ['dropout[0][0]']
#
#  dense_2 (Dense)                (None, 200)          102600      ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 26,313,288
# Trainable params: 2,725,576
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %%
# Definidiendo constantes para el ejercicio
BATCH_SIZE = 64
EPOCHS = 15

# Entrenando el modelo
hist = trainModel(birdNet, train_it, val_it, BATCH_SIZE, EPOCHS)
# Out:
# Epoch 1/15
# 43/43 [==============================] - 35s 508ms/step - loss: 5.2993 - accuracy: 0.0196 - val_loss: 4.5988 - val_accuracy: 0.1233
# Epoch 2/15
# 43/43 [==============================] - 19s 441ms/step - loss: 3.9885 - accuracy: 0.1359 - val_loss: 3.4609 - val_accuracy: 0.1667
# Epoch 3/15
# 43/43 [==============================] - 19s 443ms/step - loss: 2.8754 - accuracy: 0.3011 - val_loss: 2.8431 - val_accuracy: 0.3033
# Epoch 4/15
# 43/43 [==============================] - 19s 445ms/step - loss: 2.1988 - accuracy: 0.4233 - val_loss: 2.5854 - val_accuracy: 0.3200
# Epoch 5/15
# 43/43 [==============================] - 19s 446ms/step - loss: 1.7801 - accuracy: 0.5207 - val_loss: 2.3347 - val_accuracy: 0.3367
# Epoch 6/15
# 43/43 [==============================] - 19s 445ms/step - loss: 1.3677 - accuracy: 0.6152 - val_loss: 2.2764 - val_accuracy: 0.4300
# Epoch 7/15
# 43/43 [==============================] - 19s 447ms/step - loss: 1.1343 - accuracy: 0.6763 - val_loss: 2.3069 - val_accuracy: 0.4000
# Epoch 8/15
# 43/43 [==============================] - 19s 445ms/step - loss: 0.9498 - accuracy: 0.7296 - val_loss: 2.3562 - val_accuracy: 0.4267
# Epoch 9/15
# 43/43 [==============================] - 19s 446ms/step - loss: 0.8514 - accuracy: 0.7470 - val_loss: 2.2159 - val_accuracy: 0.4600
# Epoch 10/15
# 43/43 [==============================] - 19s 445ms/step - loss: 0.6763 - accuracy: 0.7974 - val_loss: 2.1269 - val_accuracy: 0.4533
# Epoch 11/15
# 43/43 [==============================] - 19s 446ms/step - loss: 0.6024 - accuracy: 0.8230 - val_loss: 2.2924 - val_accuracy: 0.4433
# Epoch 12/15
# 43/43 [==============================] - 19s 446ms/step - loss: 0.4553 - accuracy: 0.8607 - val_loss: 2.1430 - val_accuracy: 0.4633
# Epoch 13/15
# 43/43 [==============================] - 19s 446ms/step - loss: 0.4783 - accuracy: 0.8515 - val_loss: 2.1815 - val_accuracy: 0.4767
# Epoch 14/15
# 43/43 [==============================] - 19s 447ms/step - loss: 0.3514 - accuracy: 0.9022 - val_loss: 2.2956 - val_accuracy: 0.4533
# Epoch 15/15
# 43/43 [==============================] - 19s 443ms/step - loss: 0.3204 - accuracy: 0.9033 - val_loss: 2.2986 - val_accuracy: 0.4833

# %%
# Probando el modelo con test.
testModel(birdNet, test_x, test_y, hist)
# Out:
# Evaluando...
# 95/95 [==============================] - 22s 214ms/step - loss: 2.8011 - accuracy: 0.3950
# Resultados de Evaluación en Test
#  - Loss: 2.801098108291626
#  - Accuracy:  39.49884474277496 %

# %%
#%% Apartado 3.1.2:
# "Comparar resultados con el modelo anterior en el que únicamente se cambia 
# y reentrena la capa de salida"

# Generando el modelo
base = getResNet50('avg', train_x[0].shape)
birdNet = getBirdNetV1(base, True)

# Mostrando el modelo
birdNet.summary()

# Compilando el modelo
compileModel(birdNet)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_2[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 14, 14, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block3_add[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['conv5_block3_out[0][0]']
#  2D)
#
#  dense_3 (Dense)                (None, 200)          409800      ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 23,997,512
# Trainable params: 409,800
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %%
# Definidiendo constantes para el ejercicio
BATCH_SIZE = 64
EPOCHS = 15

# Entrenando el modelo
hist = trainModel(birdNet, train_it, val_it, BATCH_SIZE, EPOCHS)
# Out:
# Epoch 1/15
# 43/43 [==============================] - 25s 490ms/step - loss: 4.8893 - accuracy: 0.0874 - val_loss: 3.4825 - val_accuracy: 0.2233
# Epoch 2/15
# 43/43 [==============================] - 19s 446ms/step - loss: 2.0579 - accuracy: 0.5741 - val_loss: 2.6705 - val_accuracy: 0.3467
# Epoch 3/15
# 43/43 [==============================] - 19s 446ms/step - loss: 1.0861 - accuracy: 0.8389 - val_loss: 2.3283 - val_accuracy: 0.4067
# Epoch 4/15
# 43/43 [==============================] - 19s 447ms/step - loss: 0.6440 - accuracy: 0.9333 - val_loss: 2.1761 - val_accuracy: 0.4300
# Epoch 5/15
# 43/43 [==============================] - 19s 447ms/step - loss: 0.4069 - accuracy: 0.9763 - val_loss: 2.0827 - val_accuracy: 0.4833
# Epoch 6/15
# 43/43 [==============================] - 19s 446ms/step - loss: 0.2757 - accuracy: 0.9896 - val_loss: 2.0262 - val_accuracy: 0.4867
# Epoch 7/15
# 43/43 [==============================] - 19s 447ms/step - loss: 0.1967 - accuracy: 0.9967 - val_loss: 2.0046 - val_accuracy: 0.4800
# Epoch 8/15
# 43/43 [==============================] - 19s 446ms/step - loss: 0.1479 - accuracy: 0.9981 - val_loss: 1.9826 - val_accuracy: 0.4867
# Epoch 9/15
# 43/43 [==============================] - 19s 447ms/step - loss: 0.1177 - accuracy: 0.9974 - val_loss: 1.9636 - val_accuracy: 0.5200
# Epoch 10/15
# 43/43 [==============================] - 19s 448ms/step - loss: 0.0976 - accuracy: 0.9985 - val_loss: 1.9658 - val_accuracy: 0.5133
# Epoch 11/15
# 43/43 [==============================] - 19s 448ms/step - loss: 0.0788 - accuracy: 0.9981 - val_loss: 1.9505 - val_accuracy: 0.5000
# Epoch 12/15
# 43/43 [==============================] - 19s 447ms/step - loss: 0.0662 - accuracy: 0.9981 - val_loss: 1.9393 - val_accuracy: 0.5100
# Epoch 13/15
# 43/43 [==============================] - 19s 447ms/step - loss: 0.0619 - accuracy: 0.9970 - val_loss: 1.9601 - val_accuracy: 0.5233
# Epoch 14/15
# 43/43 [==============================] - 19s 448ms/step - loss: 0.0530 - accuracy: 0.9981 - val_loss: 1.9373 - val_accuracy: 0.5100
# Epoch 15/15
# 43/43 [==============================] - 19s 454ms/step - loss: 0.0464 - accuracy: 0.9978 - val_loss: 1.9456 - val_accuracy: 0.5033

# %%
# Probando el modelo con test.
testModel(birdNet, test_x, test_y, hist)
# Out:
# Evaluando...
# 95/95 [==============================] - 20s 201ms/step - loss: 2.3027 - accuracy: 0.4441
# Resultados de Evaluación en Test
#  - Loss: 2.302685022354126
#  - Accuracy:  44.41147446632385 %

# %% [markdown]
# ### Implementación del Ejercicio 3.2

# %%
#%% Apartado 3.2:
# "Eliminar las capas de salida, FC y AveragePooling, se pueden añadir ahora
# capas convolucionales también"

# Generando el modelo
base = getResNet50(None, train_x[0].shape)
birdNet = getBirdNetV2(base)

# Mostrando el modelo
birdNet.summary()

# Compilando el modelo
compileModel(birdNet)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_3[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 14, 14, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block3_add[0][0]']
#
#  conv2d (Conv2D)                (None, 7, 7, 64)     1179712     ['conv5_block3_out[0][0]']
#
#  batch_normalization (BatchNorm  (None, 7, 7, 64)    256         ['conv2d[0][0]']
#  alization)
#
#  flatten (Flatten)              (None, 3136)         0           ['batch_normalization[0][0]']
#
#  dense_4 (Dense)                (None, 256)          803072      ['flatten[0][0]']
#
#  dense_5 (Dense)                (None, 200)          51400       ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 25,622,152
# Trainable params: 2,034,312
# Non-trainable params: 23,587,840
# __________________________________________________________________________________________________

# %%
# Definidiendo constantes para el ejercicio
BATCH_SIZE = 64
EPOCHS = 15

# Entrenando el modelo
hist = trainModel(birdNet, train_it, val_it, BATCH_SIZE, EPOCHS)
# Out:
# Epoch 1/15
# 43/43 [==============================] - 26s 493ms/step - loss: 5.1414 - accuracy: 0.0337 - val_loss: 5.0624 - val_accuracy: 0.0633
# Epoch 2/15
# 43/43 [==============================] - 20s 456ms/step - loss: 2.7132 - accuracy: 0.3919 - val_loss: 4.1063 - val_accuracy: 0.1600
# Epoch 3/15
# 43/43 [==============================] - 20s 458ms/step - loss: 0.6519 - accuracy: 0.8615 - val_loss: 3.2748 - val_accuracy: 0.2767
# Epoch 4/15
# 43/43 [==============================] - 20s 457ms/step - loss: 0.1038 - accuracy: 0.9893 - val_loss: 3.1727 - val_accuracy: 0.3167
# Epoch 5/15
# 43/43 [==============================] - 20s 456ms/step - loss: 0.0290 - accuracy: 0.9985 - val_loss: 3.0320 - val_accuracy: 0.3367
# Epoch 6/15
# 43/43 [==============================] - 20s 457ms/step - loss: 0.0289 - accuracy: 0.9974 - val_loss: 2.9853 - val_accuracy: 0.3300
# Epoch 7/15
# 43/43 [==============================] - 20s 456ms/step - loss: 0.0160 - accuracy: 0.9974 - val_loss: 2.9973 - val_accuracy: 0.3567
# Epoch 8/15
# 43/43 [==============================] - 20s 457ms/step - loss: 0.0103 - accuracy: 0.9978 - val_loss: 3.0089 - val_accuracy: 0.3367
# Epoch 9/15
# 43/43 [==============================] - 20s 457ms/step - loss: 0.0132 - accuracy: 0.9981 - val_loss: 3.0109 - val_accuracy: 0.3433
# Epoch 10/15
# 43/43 [==============================] - 20s 457ms/step - loss: 0.0061 - accuracy: 0.9985 - val_loss: 2.9903 - val_accuracy: 0.3500
# Epoch 11/15
# 43/43 [==============================] - 20s 459ms/step - loss: 0.0106 - accuracy: 0.9981 - val_loss: 3.0051 - val_accuracy: 0.3467
# Epoch 12/15
# 43/43 [==============================] - 20s 456ms/step - loss: 0.0106 - accuracy: 0.9978 - val_loss: 2.9674 - val_accuracy: 0.3467
# Epoch 13/15
# 43/43 [==============================] - 20s 455ms/step - loss: 0.0070 - accuracy: 0.9978 - val_loss: 2.9907 - val_accuracy: 0.3400
# Epoch 14/15
# 43/43 [==============================] - 20s 457ms/step - loss: 0.0064 - accuracy: 0.9985 - val_loss: 2.9915 - val_accuracy: 0.3400
# Epoch 15/15
# 43/43 [==============================] - 20s 457ms/step - loss: 0.0067 - accuracy: 0.9985 - val_loss: 2.9538 - val_accuracy: 0.3667

# %%
# Probando el modelo con test.
testModel(birdNet, test_x, test_y, hist)
# Out:
# Evaluando...
# 95/95 [==============================] - 21s 205ms/step - loss: 3.2338 - accuracy: 0.2753
# Resultados de Evaluación en Test
#  - Loss: 3.233814001083374
#  - Accuracy:  27.530497312545776 %

# %% [markdown]
# ### Implementación del Ejercicio 3.3

# %%
#%% Apartado 3.3:
# "Realizar un ajuste fino de toda la red ResNet50, al conjunto de datos.
#  Caltech-UCSD"

# Generando el modelo
base = getResNet50('avg', train_x[0].shape)
birdNet = getBirdNetV3(base)

# Mostrando el modelo
birdNet.summary()

# Compilando el modelo
compileModel(birdNet)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_4[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 14, 14, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block3_add[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['conv5_block3_out[0][0]']
#  2D)
#
#  dense_6 (Dense)                (None, 200)          409800      ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 23,997,512
# Trainable params: 23,944,392
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
# Definidiendo constantes para el ejercicio.
BATCH_SIZE = 64
EPOCHS = 15

# Entrenando el modelo.
hist = trainModel(birdNet, train_it, val_it, BATCH_SIZE, EPOCHS)
# Out:
# Epoch 1/15
# 43/43 [==============================] - 66s 1s/step - loss: 5.1291 - accuracy: 0.0315 - val_loss: 520.5571 - val_accuracy: 0.0067
# Epoch 2/15
# 43/43 [==============================] - 56s 1s/step - loss: 3.5220 - accuracy: 0.1952 - val_loss: 24.2724 - val_accuracy: 0.0167
# Epoch 3/15
# 43/43 [==============================] - 56s 1s/step - loss: 2.3827 - accuracy: 0.3993 - val_loss: 10.9991 - val_accuracy: 0.0367
# Epoch 4/15
# 43/43 [==============================] - 56s 1s/step - loss: 1.3590 - accuracy: 0.6352 - val_loss: 9.8458 - val_accuracy: 0.0500
# Epoch 5/15
# 43/43 [==============================] - 57s 1s/step - loss: 0.6615 - accuracy: 0.8267 - val_loss: 7.0010 - val_accuracy: 0.1267
# Epoch 6/15
# 43/43 [==============================] - 56s 1s/step - loss: 0.4548 - accuracy: 0.8841 - val_loss: 4.9016 - val_accuracy: 0.1667
# Epoch 7/15
# 43/43 [==============================] - 56s 1s/step - loss: 0.2214 - accuracy: 0.9541 - val_loss: 5.7522 - val_accuracy: 0.1633
# Epoch 8/15
# 43/43 [==============================] - 56s 1s/step - loss: 0.1206 - accuracy: 0.9763 - val_loss: 3.7193 - val_accuracy: 0.2733
# Epoch 9/15
# 43/43 [==============================] - 56s 1s/step - loss: 0.0654 - accuracy: 0.9878 - val_loss: 3.4615 - val_accuracy: 0.2700
# Epoch 10/15
# 43/43 [==============================] - 56s 1s/step - loss: 0.0563 - accuracy: 0.9911 - val_loss: 4.3020 - val_accuracy: 0.2533
# Epoch 11/15
# 43/43 [==============================] - 56s 1s/step - loss: 0.0746 - accuracy: 0.9863 - val_loss: 3.8813 - val_accuracy: 0.2533
# Epoch 12/15
# 43/43 [==============================] - 56s 1s/step - loss: 0.0606 - accuracy: 0.9874 - val_loss: 4.1005 - val_accuracy: 0.2767
# Epoch 13/15
# 43/43 [==============================] - 56s 1s/step - loss: 0.0565 - accuracy: 0.9900 - val_loss: 3.8846 - val_accuracy: 0.2467
# Epoch 14/15
# 43/43 [==============================] - 56s 1s/step - loss: 0.0414 - accuracy: 0.9926 - val_loss: 4.3074 - val_accuracy: 0.2867
# Epoch 15/15
# 43/43 [==============================] - 56s 1s/step - loss: 0.0419 - accuracy: 0.9889 - val_loss: 4.6799 - val_accuracy: 0.2567

# %%
# Probando el modelo con test.
testModel(birdNet, test_x, test_y, hist)
# Out:
# Evaluando...
# 95/95 [==============================] - 20s 201ms/step - loss: 5.4460 - accuracy: 0.1929
# Resultados de Evaluación en Test
#  - Loss: 5.446008682250977
#  - Accuracy:  19.28783357143402 %
